# %%
#merge sort

# %%
import pandas as pd
import os

# %%
os.list('/temp/diamonds.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18872/2167822201.py in <module>
# ----> 1 os.list('/temp/diamonds.csv')
#
# AttributeError: module 'os' has no attribute 'list'

# %%
print(os.pardir)
# Out:
# ..
